# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://jportal.mdcourts.gov/license/index_disclaimer.jsp")

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages.
#
# ### How will you identify the checkbox to check it?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?
#
# - *TIP: I have a secret awesome way to do this, but you have to ask.*

# %%
checkbox = driver.find_element_by_xpath('//*[@id="checkbox"]')

# %%
checkbox.click()

# %% [markdown]
# ### How will you identify the button to select it, or the form to submit it?
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**

# %%
enter_the_site = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
enter_the_site.click()

# %% [markdown]
# ### Once you're on the next page, how will you click the "SEARCH LICENSE RECORDS" link or follow its URL?

# %%
search_license_record = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
search_license_record.click()

# %% [markdown]
# ### Now you're on the form page. How do you pick "Statewide" for the jurisdiction dropdown?

# %%
from selenium.webdriver.support.ui import Select

# %%
jurisdition = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
# convert a element into a select that selenium could understand
jurisdition_select = Select(jurisdition)
jurisdition_select.select_by_visible_text('Statewide')

# %% [markdown]
# ### How do you type "vap%" into the Trade Name field?

# %%
from selenium.webdriver.common.keys import Keys
trade_name = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
trade_name.send_keys('vap%')

# %% [markdown]
# ### How do you click the submit button or submit the form?

# %%
trade_name.send_keys(Keys.RETURN)

# %% [markdown]
# ### How can you find and click the 'Next' button on the search results page?

# %%
next = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
next.click()

# %% [markdown]
# # Okay, let's scrape!
#
# ### Use Selenium to search for vape shops statewide, and then click through until it reaches the last page.
#
# Don't scrape yet!

# %%
while True:
    try:
        driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr').click()
    except:
        break

# %% [markdown]
# ### Use Selenium to scrape the first page of search results for vape shops statewide (well, we'll try).
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source,'html.parser')`*
#
# I've included some BeautifulSoup code that might be helpful. If you use it, **ask me how I made it.** It's important.

# %%
from bs4 import BeautifulSoup
import requests

# %%
doc = BeautifulSoup(driver.page_source, 'html.parser')
doc
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="EN" xmlns="http://www.w3.org/1999/xhtml"><head>
# <title>Maryland Judiciary Business Licenses Online</title>
# <link href="theme/styles.css" rel="STYLESHEET" type="text/css"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# </head>
# <body>
# <!-- HEADER AREA - Header graphic, company logo and link images go here-->
# <table border="0" cellpadding="0" cellspacing="0" summary="Page Layout Table" width="100%">
# <tbody><tr>
# <td colspan="3">
# <img alt="MARYLAND BUSINESS LICENSES ONLINE" height="66" src="images/header_new.gif" width="596"/><img alt="" src="images/spacer.gif" width="35"/>
# </td>
# </tr>
# <tr>
# <td class="headerline">
# <img alt="blank spacer" height="18" src="images/spacer.gif" width="35"/>
# </td>
# <td align="LEFT" class="headerline">
# <table border="0" cellpadding="0" cellspacing="0" summary="Navigation Menu">
# <tbody><tr valign="top">
# <td>
# <img alt="" height="18" src="images/nav-leftedgebar.gif" width="30"/>
# </td>
# <td>
# <a href="pbIndex.jsp"><img alt="HOME" height="18" src="images/nav-home.gif" width="54"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbPublicSearch.jsp?newSearch=true">
# <img alt="SEARCH" height="18" src="images/nav-search.gif" width="153"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbDecisionTreeSteps.jsp"><img alt="NEW LICENSE" height="18" src="images/nav-newlicense.gif" width="88"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbApplyRenewLicense.jsp"><img alt="EDIT/RENEW LICENSE" height="18" src="images/nav-editrenewlicense.gif" width="133"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbPaymentHome.jsp"><img alt="MAKE A PAYMENT" height="18" src="images/nav-makepayment.gif" width="111"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbLinks.jsp"><img alt="LINKS" height="18" src="images/nav-links.gif" width="51"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbContactList.jsp"><img alt="CONTACT US" height="18" src="images/nav-contact.gif" width="85"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbHelp.jsp"><img alt="HELP" height="18" src="images/nav-help.gif" width="37"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <img alt="EDGE" height="18" src="images/navrightedgebar.gif" width="30"/>
# </td>
# </tr>
# </tbody></table>
# </td>
# <td class="headerline">
# <img alt="" height="18" src="images/spacer.gif"/>
# </td>
# </tr>
# </tbody></table>
# <!-- END HEADER AREA -->
# <table border="0" cellpadding="0" cellspacing="0" summary="Page Footer Area" width="100%">
# <tbody><tr valign="TOP">
# <td><img alt="" height="10" src="images/spacer.gif" width="105"/></td>
# <td><img alt="" height="10" src="images/spacer.gif"/></td>
# <td><img alt="" height="10" src="images/spacer.gif" width="100"/></td>
# <td><img alt="" height="10" src="images/spacer.gif" width="180"/></td>
# <td><img alt="" height="10" src="images/spacer.gif" width="100"/></td>
# </tr>
# <!-- DIRECTORY - This area is designated for the location of the current page being viewed so the enduser can easily determine his/her location within this website-->
# <tr>
# <td><img alt="" height="1" src="images/spacer.gif" width="105"/></td>
# <td class="copy" colspan="4"><a href="pbIndex.jsp">HOME</a> &gt; <a href="pbPublicSearch.jsp?newSearch=true">Search License</a> &gt; Search Results</td>
# </tr>
# <!-- END DIRECTORY LINE -->
# <tr valign="top">
# <td colspan="5"><img alt="" height="25" src="images/spacer.gif"/></td>
# </tr>
# <!-- CONTENT AREA - This is the main section that contains all the main information for this page -->
# <tr valign="top">
# <td><img alt="" src="images/spacer.gif" width="105"/></td>
# <td>
# <!-- HEADLINE -->
# <div class="headline">Search License Results</div>
# <!-- GREETING OR INSTRUCTION - The following section contains either a greeting or direction/information of items on this page -->
# <div class="copy">Below you will find the results to your License Search.<p>
# </p><p>Not all businesses require a license issued by the Clerk of the Circuit Court.  Not all licenses are required in all counties.  The information provided is a representation of the records in the Clerk of the Circuit Court's office and is not guaranteed to be complete.  If you have questions concerning licensing please contact the Clerk of the Circuit Court's office in the county in which the business is located.  If you wish to report a business that you believe is operating without a license please contact the Comptroller of the Treasury - Business License Enforcement Division at 410-260-6240.</p>
# 				You searched for<br/>
# 				    <span class="copybold">Trade Name</span> vap%<br/>
#
#
# 				    <span class="copybold">Jurisdiction</span>
#                                 Statewide<br/>
# 				    <span class="copybold">Year</span> 2017<br/>
# <!-- CONTENT AREA -->
# <p>Displaying <span class="copybold">1-5</span> (of 32) matching your criteria</p><p></p></div>
# <div class="copybold">You may wish to reduce your search criteria to increase the number of responses found</div>
# <p>
# </p><table summary="Search Results Table">
# <tbody><tr><td colspan="3"><img alt="" height="16" src="images/spacer.gif" width="482"/></td></tr>
# <tr><td class="searchlistred" colspan="3">* Note : Detailed License Information is not available for Licenses which show a status of Pending</td></tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">1.</td>
# <td class="searchlistitem"><span class="copybold">VAPE IT STORE I</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=CpY1fUg7okk%3D"><img alt="Click for Detail of VAPE IT STORE I" src="images/link_click-detail.gif"/></a></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>AMIN NARGIS</td>
# <td><span class="copybold">Lic. Status:</span> Issued</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>1724 N SALISBURY BLVD UNIT 2</td>
# <td><span class="copybold">License:</span> 22173807</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>SALISBURY, MD 21801</td>
# <td><span class="copybold">Issued Date:</span> 4/27/2017</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Wicomico County</td>
# <td></td>
# </tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">2.</td>
# <td class="searchlistitem"><span class="copybold">VAPE IT STORE II</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=LVmS56v8b84%3D"><img alt="Click for Detail of VAPE IT STORE II" src="images/link_click-detail.gif"/></a></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>AMIN NARGIS</td>
# <td><span class="copybold">Lic. Status:</span> Issued</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>1015 S SALISBURY BLVD</td>
# <td><span class="copybold">License:</span> 22173808</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>SALISBURY, MD 21801</td>
# <td><span class="copybold">Issued Date:</span> 4/27/2017</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Wicomico County</td>
# <td></td>
# </tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">3.</td>
# <td class="searchlistitem"><span class="copybold">VAPEPAD THE</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=aKoi%2B3HaLg4%3D"><img alt="Click for Detail of VAPEPAD THE" src="images/link_click-detail.gif"/></a></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>ANJ DISTRIBUTIONS LLC</td>
# <td><span class="copybold">Lic. Status:</span> Issued</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>2299 JOHNS HOPKINS ROAD</td>
# <td><span class="copybold">License:</span> 02104436</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>GAMBRILLS, MD 21054</td>
# <td><span class="copybold">Issued Date:</span> 4/05/2017</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Anne Arundel County</td>
# <td></td>
# </tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">4.</td>
# <td class="searchlistitem"><span class="copybold">VAPE FROG</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=c5NgWVo2apQ%3D"><img alt="Click for Detail of VAPE FROG" src="images/link_click-detail.gif"/></a></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>COX TRADING COMPANY L L C</td>
# <td><span class="copybold">Lic. Status:</span> Issued</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>110 S. PINEY RD</td>
# <td><span class="copybold">License:</span> 17165957</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>CHESTER, MD 21619</td>
# <td><span class="copybold">Issued Date:</span> 5/31/2017</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Queen Anne's County</td>
# <td></td>
# </tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">5.</td>
# <td class="searchlistitem"><span class="copybold">VAPE FROG</span></td>
# <td>Pending <span class="searchlistred">*</span></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>COX TRADING LLC</td>
# <td><span class="copybold">Lic. Status:</span> Pending</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>346 RITCHIE HIGHWAY</td>
# <td></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>SEVERNA PARK, MD 21146</td>
# <td></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Anne Arundel County</td>
# <td></td>
# </tr>
# </tbody></table>
# <table class="btmnavtable" summary="Bottom Navigation">
# <tbody><tr>
# <td align="left"></td>
# <td align="center" class="tablecelltext">Page:
#
#                                     <span class="copybold">1</span>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=5">2</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=10">3</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=15">4</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=20">5</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=25">6</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=30">7</a>
# </td>
# <td align="right">
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=5"><nobr>Next »</nobr></a>
# </td>
# </tr>
# </tbody></table>
# <!-- END CONTENT AREA -->
# </td>
# <td><img alt="" src="images/spacer.gif" width="100"/></td>
# <td>
# <!-- DYNAMIC GOLD BOX - This message box appears on all pages and contains up-to-date information, FAQ, important updates or key point on the current page -->
# <table class="copy" summary="Helpful Information Area">
# <tbody><tr>
# <td>
# <div class="bl">
# <div class="br">
# <div class="tl">
# <div class="tr">
# <div class="boxintroheader">Get the right license</div><br/>
# <div class="boxheadline">"How do I get started?"</div><br/>
# <div class="hrline"><img alt="." src="images/spacer-red.gif"/></div><br/>
# <div class="copy"><a href="pbStartabusiness.jsp">Starting a new business in Maryland?</a><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# <div class="copy"><a href="pbFaq.jsp">FAQ-Frequently Asked Questions</a><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# <div class="copy"><a href="pbLaw.jsp">MD Law Title 17</a><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# <div class="copy"><a href="pbContactList.jsp">View contact information for all Clerks of the Circuit Court</a><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# <div class="hrline"><img alt="." src="images/spacer-red.gif"/></div><br/>
# <div class="boxheadline">Helpful Hints</div><br/>
# <div class="copybold">Use the "click for detail" link to see the Business License information</div><br/>
# <div class="hrline"><img alt="." src="images/spacer-red.gif"/></div><br/>
# <div class="copybold">If you want to add or edit/renew a license,<br/><a href="pbLogin.jsp"><div class="">PLEASE LOGIN HERE.</div></a></div><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# </div>
# </div>
# </div>
# <div class="clear"> </div>
# </td>
# </tr>
# <!--What's New text-->
# <!--End What's New text-->
# </tbody></table>
# <!-- END DYNAMIC BOX -->
# </td>
# <td><img alt="" src="images/spacer.gif"/></td>
# </tr>
# <tr>
# <td colspan="5"><img alt="" height="25" src="images/spacer.gif" width="100"/></td>
# </tr>
# <!-- FOOTER NAVIGATION - This area contains all navigation links found in header area in text format -->
# <tr>
# <td><img alt="" height="1" src="images/spacer.gif" width="100"/></td>
# <td class="divider" colspan="4">
# <a href="pbIndex.jsp">HOME</a> |
#             <a href="pbPublicSearch.jsp?newSearch=true">SEARCH LICENSE RECORDS</a> |
#             <a href="pbDecisionTreeSteps.jsp">NEW LICENSE</a> |
#             <a href="pbApplyRenewLicense.jsp">EDIT/RENEW LICENSES</a> |
#             <a href="pbPaymentHome.jsp">MAKE A PAYMENT</a> |
#             <a href="pbLinks.jsp">LINKS</a> |
#             <a href="pbContactList.jsp">CONTACT US</a> |
#             <a href="pbHelp.jsp">HELP</a>
# </td>
# </tr>
# <!-- DISCLAIMER-->
# <tr>
# <td colspan="5"><img alt="" height="25" src="images/spacer.gif" width="100"/></td>
# </tr>
# <tr>
# <td><img alt="" height="1" src="images/spacer.gif" width="100"/></td>
# <td class="legaldisclaimer" colspan="3">The Maryland Judiciary, its agencies, officers, or employees do not guarantee the accuracy, reliability or
#         timeliness of any information contained in this system.  Users rely on this information at their own risk.</td>
# <td></td>
# </tr>
# <!-- END DISCLAIMER-->
# <!-- END FOOTER NAVIGATION -->
# </tbody></table>
# </body></html>

# %%
business_headers = doc.find_all('tr',class_='searchfieldtitle')
len(business_headers)
# Out:
# 5

# %%
for header in business_headers:
    rows = header.find_next_siblings('tr')
    print("HEADER is", header.text.strip())
    print("ROW 0 IS", rows[0].text.strip())
    print("ROW 1 IS", rows[1].text.strip())
    print("ROW 2 IS", rows[2].text.strip())
    print("ROW 3 IS", rows[3].text.strip())
    print("----")
# Out:
# HEADER is 1.
# VAPE IT STORE I
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1724 N SALISBURY BLVD UNIT 2
# License: 22173807
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 2.
# VAPE IT STORE II
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1015 S SALISBURY BLVD
# License: 22173808
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 3.
# VAPEPAD THE
# ROW 0 IS ANJ DISTRIBUTIONS LLC
# Lic. Status: Issued
# ROW 1 IS 2299 JOHNS HOPKINS ROAD
# License: 02104436
# ROW 2 IS GAMBRILLS, MD 21054
# Issued Date: 4/05/2017
# ROW 3 IS Anne Arundel County
# ----
# HEADER is 4.
# VAPE FROG
# ROW 0 IS COX TRADING COMPANY L L C
# Lic. Status: Issued
# ROW 1 IS 110 S. PINEY RD
# License: 17165957
# ROW 2 IS CHESTER, MD 21619
# Issued Date: 5/31/2017
# ROW 3 IS Queen Anne's County
# ----
# HEADER is 5.
# VAPE FROG
# Pending *
# ROW 0 IS COX TRADING LLC
# Lic. Status: Pending
# ROW 1 IS 346 RITCHIE HIGHWAY
# ROW 2 IS SEVERNA PARK, MD 21146
# ROW 3 IS Anne Arundel County
# ----

# %% [markdown]
# ### Save these into `vape-results.csv`

# %%
business_headers[0].find_next_siblings('tr')
# Out:
# [<tr class="tablecelltext">
#  <td> </td>
#  <td>AMIN NARGIS</td>
#  <td><span class="copybold">Lic. Status:</span> Issued</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>1724 N SALISBURY BLVD UNIT 2</td>
#  <td><span class="copybold">License:</span> 22173807</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>SALISBURY, MD 21801</td>
#  <td><span class="copybold">Issued Date:</span> 4/27/2017</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>Wicomico County</td>
#  <td></td>
#  </tr>, <tr class="searchfieldtitle">
#  <td class="searchlistnumber">2.</td>
#  <td class="searchlistitem"><span class="copybold">VAPE IT STORE II</span></td>
#  <td><a href="pbLicenseDetail.jsp?owi=LVmS56v8b84%3D"><img alt="Click for Detail of VAPE IT STORE II" src="images/link_click-detail.gif"/></a></td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>AMIN NARGIS</td>
#  <td><span class="copybold">Lic. Status:</span> Issued</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>1015 S SALISBURY BLVD</td>
#  <td><span class="copybold">License:</span> 22173808</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>SALISBURY, MD 21801</td>
#  <td><span class="copybold">Issued Date:</span> 4/27/2017</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>Wicomico County</td>
#  <td></td>
#  </tr>, <tr class="searchfieldtitle">
#  <td class="searchlistnumber">3.</td>
#  <td class="searchlistitem"><span class="copybold">VAPEPAD THE</span></td>
#  <td><a href="pbLicenseDetail.jsp?owi=aKoi%2B3HaLg4%3D"><img alt="Click for Detail of VAPEPAD THE" src="images/link_click-detail.gif"/></a></td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>ANJ DISTRIBUTIONS LLC</td>
#  <td><span class="copybold">Lic. Status:</span> Issued</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>2299 JOHNS HOPKINS ROAD</td>
#  <td><span class="copybold">License:</span> 02104436</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>GAMBRILLS, MD 21054</td>
#  <td><span class="copybold">Issued Date:</span> 4/05/2017</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>Anne Arundel County</td>
#  <td></td>
#  </tr>, <tr class="searchfieldtitle">
#  <td class="searchlistnumber">4.</td>
#  <td class="searchlistitem"><span class="copybold">VAPE FROG</span></td>
#  <td><a href="pbLicenseDetail.jsp?owi=c5NgWVo2apQ%3D"><img alt="Click for Detail of VAPE FROG" src="images/link_click-detail.gif"/></a></td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>COX TRADING COMPANY L L C</td>
#  <td><span class="copybold">Lic. Status:</span> Issued</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>110 S. PINEY RD</td>
#  <td><span class="copybold">License:</span> 17165957</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>CHESTER, MD 21619</td>
#  <td><span class="copybold">Issued Date:</span> 5/31/2017</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>Queen Anne's County</td>
#  <td></td>
#  </tr>, <tr class="searchfieldtitle">
#  <td class="searchlistnumber">5.</td>
#  <td class="searchlistitem"><span class="copybold">VAPE FROG</span></td>
#  <td>Pending <span class="searchlistred">*</span></td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>COX TRADING LLC</td>
#  <td><span class="copybold">Lic. Status:</span> Pending</td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>346 RITCHIE HIGHWAY</td>
#  <td></td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>SEVERNA PARK, MD 21146</td>
#  <td></td>
#  </tr>, <tr class="tablecelltext">
#  <td> </td>
#  <td>Anne Arundel County</td>
#  <td></td>
#  </tr>]

# %%
for header in business_headers:
    rows = header.find_next_siblings('tr')
    print("HEADER is", header.text.strip())
    print("ROW 0 IS", rows[0].text.strip())
    print("ROW 1 IS", rows[1].text.strip())
    print("ROW 2 IS", rows[2].text.strip())
    print("ROW 3 IS", rows[3].text.strip())
    print("----")
# Out:
# HEADER is 1.
# VAPE IT STORE I
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1724 N SALISBURY BLVD UNIT 2
# License: 22173807
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 2.
# VAPE IT STORE II
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1015 S SALISBURY BLVD
# License: 22173808
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# ----
# HEADER is 3.
# VAPEPAD THE
# ROW 0 IS ANJ DISTRIBUTIONS LLC
# Lic. Status: Issued
# ROW 1 IS 2299 JOHNS HOPKINS ROAD
# License: 02104436
# ROW 2 IS GAMBRILLS, MD 21054
# Issued Date: 4/05/2017
# ROW 3 IS Anne Arundel County
# ----
# HEADER is 4.
# VAPE FROG
# ROW 0 IS COX TRADING COMPANY L L C
# Lic. Status: Issued
# ROW 1 IS 110 S. PINEY RD
# License: 17165957
# ROW 2 IS CHESTER, MD 21619
# Issued Date: 5/31/2017
# ROW 3 IS Queen Anne's County
# ----
# HEADER is 5.
# VAPE FROG
# Pending *
# ROW 0 IS COX TRADING LLC
# Lic. Status: Pending
# ROW 1 IS 346 RITCHIE HIGHWAY
# ROW 2 IS SEVERNA PARK, MD 21146
# ROW 3 IS Anne Arundel County
# ----

# %%
vape_shops = []

for header in business_headers:
    rows = header.find_next_siblings('tr')
    if rows[2].find_all('td')[2].find('span', attrs={'class':'copybold'}):
        issued_date = rows[2].find_all('td')[2].find('span', attrs={'class':'copybold'}).next.next[1:]
    if rows[1].find_all('td')[2].find('span', attrs={'class':'copybold'}):
        license = rows[1].find_all('td')[2].find('span', attrs={'class':'copybold'}).next.next[1:]
    if rows[0].find_all('td')[2].find('span', attrs={'class':'copybold'}):
        status = rows[0].find_all('td')[2].find('span', attrs={'class':'copybold'}).next.next[1:]
    vape_shops.append({
        'header': header.find_all('td')[0].text.strip(),
        'shop name': header.find_all('td')[1].text.strip(),
        'company': rows[0].find_all('td')[1].text.strip(),
        'address': rows[1].find_all('td')[1].text.strip(),
        'county': rows[2].find_all('td')[1].text.strip(),
        'status': status,
        'license': license,
        'issued date': issued_date
    })

vape_shops
# Out:
# [{'address': '1724 N SALISBURY BLVD UNIT 2',
#   'company': 'AMIN NARGIS',
#   'county': 'SALISBURY, MD 21801',
#   'header': '1.',
#   'issued date': '4/27/2017',
#   'license': '22173807',
#   'shop name': 'VAPE IT STORE I',
#   'status': 'Issued'},
#  {'address': '1015 S SALISBURY BLVD',
#   'company': 'AMIN NARGIS',
#   'county': 'SALISBURY, MD 21801',
#   'header': '2.',
#   'issued date': '4/27/2017',
#   'license': '22173808',
#   'shop name': 'VAPE IT STORE II',
#   'status': 'Issued'},
#  {'address': '2299 JOHNS HOPKINS ROAD',
#   'company': 'ANJ DISTRIBUTIONS LLC',
#   'county': 'GAMBRILLS, MD 21054',
#   'header': '3.',
#   'issued date': '4/05/2017',
#   'license': '02104436',
#   'shop name': 'VAPEPAD THE',
#   'status': 'Issued'},
#  {'address': '110 S. PINEY RD',
#   'company': 'COX TRADING COMPANY L L C',
#   'county': 'CHESTER, MD 21619',
#   'header': '4.',
#   'issued date': '5/31/2017',
#   'license': '17165957',
#   'shop name': 'VAPE FROG',
#   'status': 'Issued'},
#  {'address': '346 RITCHIE HIGHWAY',
#   'company': 'COX TRADING LLC',
#   'county': 'SEVERNA PARK, MD 21146',
#   'header': '5.',
#   'issued date': '5/31/2017',
#   'license': '17165957',
#   'shop name': 'VAPE FROG',
#   'status': 'Pending'}]

# %% [markdown]
# ### Open `vape-results.csv` to make sure there aren't any extra weird columns

# %%
import pandas as pd

# %%
df = pd.DataFrame(vape_shops)
df.head()
# Out:
#                         address                    company  \
# 0  1724 N SALISBURY BLVD UNIT 2                AMIN NARGIS
# 1         1015 S SALISBURY BLVD                AMIN NARGIS
# 2       2299 JOHNS HOPKINS ROAD      ANJ DISTRIBUTIONS LLC
# 3               110 S. PINEY RD  COX TRADING COMPANY L L C
# 4           346 RITCHIE HIGHWAY            COX TRADING LLC
#
#                    county header issued date   license         shop name  \
# 0     SALISBURY, MD 21801     1.   4/27/2017  22173807   VAPE IT STORE I
# 1     SALISBURY, MD 21801     2.   4/27/2017  22173808  VAPE IT STORE II
# 2     GAMBRILLS, MD 21054     3.   4/05/2017  02104436       VAPEPAD THE
# 3       CHESTER, MD 21619     4.   5/31/2017  17165957         VAPE FROG
# 4  SEVERNA PARK, MD 21146     5.   5/31/2017  17165957         VAPE FROG
#
#     status
# 0   Issued
# 1   Issued
# 2   Issued
# 3   Issued
# 4  Pending

# %%
df.to_csv("vape-results.csv", index=False)

# %% [markdown]
# ## Use Selenium to scrape ALL pages of results, save the results into `vape-results-all.csv`.

# %%
vape_shops_all = []

while True:
    doc = BeautifulSoup(driver.page_source, 'html.parser')
    
    business_headers = doc.find_all('tr',class_='searchfieldtitle')
        
    for header in business_headers:
        rows = header.find_next_siblings('tr')
        if rows[2].find_all('td')[2].find('span', attrs={'class':'copybold'}):
            issued_date = rows[2].find_all('td')[2].find('span', attrs={'class':'copybold'}).next.next[1:]
        if rows[1].find_all('td')[2].find('span', attrs={'class':'copybold'}):
            license = rows[1].find_all('td')[2].find('span', attrs={'class':'copybold'}).next.next[1:]
        if rows[0].find_all('td')[2].find('span', attrs={'class':'copybold'}):
            status = rows[0].find_all('td')[2].find('span', attrs={'class':'copybold'}).next.next[1:]
        vape_shops_all.append({
            'header': header.find_all('td')[0].text.strip(),
            'shop name': header.find_all('td')[1].text.strip(),
            'company': rows[0].find_all('td')[1].text.strip(),
            'address': rows[1].find_all('td')[1].text.strip(),
            'county': rows[2].find_all('td')[1].text.strip(),
            'status': status,
            'license': license,
            'issued date': issued_date
        })
    try:            
        driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr').click()
        
    except:
        break
        
vape_shops_all
# Out:
# [{'address': '1724 N SALISBURY BLVD UNIT 2',
#   'company': 'AMIN NARGIS',
#   'county': 'SALISBURY, MD 21801',
#   'header': '1.',
#   'issued date': '4/27/2017',
#   'license': '22173807',
#   'shop name': 'VAPE IT STORE I',
#   'status': 'Issued'},
#  {'address': '1015 S SALISBURY BLVD',
#   'company': 'AMIN NARGIS',
#   'county': 'SALISBURY, MD 21801',
#   'header': '2.',
#   'issued date': '4/27/2017',
#   'license': '22173808',
#   'shop name': 'VAPE IT STORE II',
#   'status': 'Issued'},
#  {'address': '2299 JOHNS HOPKINS ROAD',
#   'company': 'ANJ DISTRIBUTIONS LLC',
#   'county': 'GAMBRILLS, MD 21054',
#   'header': '3.',
#   'issued date': '4/05/2017',
#   'license': '02104436',
#   'shop name': 'VAPEPAD THE',
#   'status': 'Issued'},
#  {'address': '110 S. PINEY RD',
#   'company': 'COX TRADING COMPANY L L C',
#   'county': 'CHESTER, MD 21619',
#   'header': '4.',
#   'issued date': '5/31/2017',
#   'license': '17165957',
#   'shop name': 'VAPE FROG',
#   'status': 'Issued'},
#  {'address': '346 RITCHIE HIGHWAY',
#   'company': 'COX TRADING LLC',
#   'county': 'SEVERNA PARK, MD 21146',
#   'header': '5.',
#   'issued date': '5/31/2017',
#   'license': '17165957',
#   'shop name': 'VAPE FROG',
#   'status': 'Pending'},
#  {'address': '185 MITCHELLS CHANCE RD',
#   'company': 'DISBROW II EMERSON HARRINGTON',
#   'county': 'EDGEWATER, MD 21037',
#   'header': '6.',
#   'issued date': '4/13/2017',
#   'license': '02102408',
#   'shop name': 'VAPE LOFT (THE)',
#   'status': 'Issued'},
#  {'address': '7104 MINSTREL UNIT #7',
#   'company': 'DISCOUNT TOBACCO ESSEX LLC',
#   'county': 'COLUMBIA, MD 21045',
#   'header': '7.',
#   'issued date': '5/19/2017',
#   'license': '13141786',
#   'shop name': 'VAPE N CIGAR',
#   'status': 'Issued'},
#  {'address': '330 ONE FORTY VILLAGE ROAD',
#   'company': 'FAIRGROUND VILLAGE LLC',
#   'county': 'WESTMINSTER, MD 21157',
#   'header': '8.',
#   'issued date': '4/21/2017',
#   'license': '06126253',
#   'shop name': 'VAPE DOJO',
#   'status': 'Issued'},
#  {'address': '29890 THREE NOTCH ROAD',
#   'company': 'GRIMM JENNIFER',
#   'county': 'CHARLOTTE HALL, MD 20622',
#   'header': '9.',
#   'issued date': '4/21/2017',
#   'license': '06126253',
#   'shop name': 'VAPE HAVEN',
#   'status': 'Pending'},
#  {'address': '356 ROMANCOKE ROAD',
#   'company': 'HUTCH VAPES LLC',
#   'county': 'STEVENSVILLE, MD 21666',
#   'header': '10.',
#   'issued date': '4/13/2017',
#   'license': '17166688',
#   'shop name': 'VAPE BIRD',
#   'status': 'Issued'},
#  {'address': '110 S PINEY ROAD  STE 106',
#   'company': 'HUTCHINS COX LLP',
#   'county': 'CHESTER, MD 21619',
#   'header': '11.',
#   'issued date': '4/13/2017',
#   'license': '17166688',
#   'shop name': 'VAPE FROG',
#   'status': 'Pending'},
#  {'address': '28943 THREE NOTCH ROAD',
#   'company': 'JAMESON WILLIAM',
#   'county': 'MECHANICSVILLE, MD 20659',
#   'header': '12.',
#   'issued date': '5/17/2017',
#   'license': '18167503',
#   'shop name': 'VAPORS LOUNGE',
#   'status': 'Issued'},
#  {'address': '6843 CRAIN HIGHWAY',
#   'company': 'JAMESON WILLIAM E',
#   'county': 'LA PLATA, MD 20646',
#   'header': '13.',
#   'issued date': '5/17/2017',
#   'license': '18167503',
#   'shop name': 'VAPORS LOUNGE',
#   'status': 'Pending'},
#  {'address': '6321 OLD BRANCH AVE',
#   'company': 'JEFFERS MICHAEL',
#   'county': 'CAMP SPRINGS, MD 20748',
#   'header': '14.',
#   'issued date': '5/17/2017',
#   'license': '18167503',
#   'shop name': 'VAPIST MD',
#   'status': 'Pending'},
#  {'address': '6321 OLD BRANCH AVE',
#   'company': 'JEFFERS MICHAEL W',
#   'county': 'CAMP SPRINGS, MD 20748',
#   'header': '15.',
#   'issued date': '5/17/2017',
#   'license': '18167503',
#   'shop name': 'VAPIST MD LLC',
#   'status': 'Pending'},
#  {'address': '7954 B AND A BLVD',
#   'company': 'SHIN JENNY Y',
#   'county': 'GLEN BURNIE, MD 21060',
#   'header': '16.',
#   'issued date': '5/17/2017',
#   'license': '18167503',
#   'shop name': 'VAPERTETMD',
#   'status': 'Pending'},
#  {'address': '6325 WASHINGTON BLVD',
#   'company': 'SHIN JENNY YOUNG',
#   'county': 'ELKRIDGE, MD 21075',
#   'header': '17.',
#   'issued date': '5/17/2017',
#   'license': '18167503',
#   'shop name': 'VAPERTEKMD',
#   'status': 'Pending'},
#  {'address': '3203 NORTH POINT RD',
#   'company': 'TAYLOR TRAVIS',
#   'county': 'BALTIMORE, MD 21222',
#   'header': '18.',
#   'issued date': '5/17/2017',
#   'license': '18167503',
#   'shop name': 'VAPORIOT',
#   'status': 'Pending'},
#  {'address': '519 LINDEN AVENUE UNIT 6',
#   'company': 'TRUE ENTERPRISE INC',
#   'county': 'POCOMOKE CITY, MD 21851',
#   'header': '19.',
#   'issued date': '5/05/2017',
#   'license': '23178140',
#   'shop name': 'VAPE PLUS',
#   'status': 'Issued'},
#  {'address': '16521 S FREDERICK AVE',
#   'company': 'VAPE  SOCIAL  LLC',
#   'county': 'GAITHERSBURG, MD 20877',
#   'header': '20.',
#   'issued date': '4/18/2017',
#   'license': '15155429',
#   'shop name': 'VAPE  SOCIAL',
#   'status': 'Issued'},
#  {'address': '2070 CRAIN HIGHWAY  UNIT F',
#   'company': 'VAPE JUNGLE LLC',
#   'county': 'WALDORF, MD 20601',
#   'header': '21.',
#   'issued date': '3/31/2017',
#   'license': '08131285',
#   'shop name': 'VAPE JUNGLE',
#   'status': 'Issued'},
#  {'address': '4130 E JOPPA RD UNIT 109',
#   'company': 'VAPE TIME LLC',
#   'county': 'NOTTINGHAM, MD 21236',
#   'header': '22.',
#   'issued date': '3/31/2017',
#   'license': '08131285',
#   'shop name': 'VAPE TIME',
#   'status': 'Pending'},
#  {'address': '11110 MALL CIRCLE',
#   'company': 'VAPEBAR EXPRESS LLC',
#   'county': 'WALDORF, MD 20603',
#   'header': '23.',
#   'issued date': '3/31/2017',
#   'license': '08131285',
#   'shop name': 'VAPEBAR EXPESS',
#   'status': 'Pending'},
#  {'address': '3524 CRAIN HWY',
#   'company': 'VAPOR 99 LLC',
#   'county': 'BOWIE, MD 20716',
#   'header': '24.',
#   'issued date': '5/03/2017',
#   'license': '16165362',
#   'shop name': 'VAPOR 99',
#   'status': 'Issued'},
#  {'address': '8117 OCEAN GATEWAY UNIT #4',
#   'company': 'VAPOR ALLEY LLC',
#   'county': 'EASTON, MD 21601',
#   'header': '25.',
#   'issued date': '5/10/2017',
#   'license': '20170900',
#   'shop name': 'VAPOR ALLEY',
#   'status': 'Issued'},
#  {'address': '11717 OLD NATIONAL PIKE',
#   'company': 'VAPOR EMPORIUM MD LLC',
#   'county': 'NEW MARKET, MD 21774',
#   'header': '26.',
#   'issued date': '4/14/2017',
#   'license': '10135432',
#   'shop name': 'VAPOR EMPORIUM',
#   'status': 'Issued'},
#  {'address': '1913 LANSDOWNE ROAD SUITE E',
#   'company': 'VAPOR VILLA CORP',
#   'county': 'BALTIMORE, MD 21227',
#   'header': '27.',
#   'issued date': '4/12/2017',
#   'license': '03121958',
#   'shop name': 'VAPOR VILLA',
#   'status': 'Issued'},
#  {'address': '730 FREDERICK ROAD',
#   'company': 'VAPOR VILLA CORP',
#   'county': 'CATONSVILLE, MD 21228',
#   'header': '28.',
#   'issued date': '4/12/2017',
#   'license': '03121959',
#   'shop name': 'VAPOR VILLA',
#   'status': 'Issued'},
#  {'address': '138 N BOND STREET',
#   'company': 'WALKER TRADING CO INC',
#   'county': 'BEL AIR, MD 21014',
#   'header': '29.',
#   'issued date': '4/03/2017',
#   'license': '12140135',
#   'shop name': 'VAPE DOJO',
#   'status': 'Issued'},
#  {'address': '11600 CROSSROAD CIR  STE E',
#   'company': 'WALKER TRADING COMPANY INC',
#   'county': 'BALTIMORE, MD 21220',
#   'header': '30.',
#   'issued date': '4/03/2017',
#   'license': '12140135',
#   'shop name': 'VAPE DOJO',
#   'status': 'Pending'},
#  {'address': '11600 CROSSROAD CIR  STE E',
#   'company': 'WALKER TRADING COMPANY INC',
#   'county': 'BALTIMORE, MD 21220',
#   'header': '31.',
#   'issued date': '4/03/2017',
#   'license': '12140135',
#   'shop name': 'VAPE DOJO',
#   'status': 'Pending'},
#  {'address': '3315 PLAZA WAY',
#   'company': 'YARKHOUSE EMPIRE INC',
#   'county': 'WALDORF, MD 20603',
#   'header': '32.',
#   'issued date': '4/03/2017',
#   'license': '12140135',
#   'shop name': 'VAPEZ YARDHOUSE',
#   'status': 'Pending'}]

# %%
len(vape_shops_all)
# Out:
# 32

# %%
df_1 = pd.DataFrame(vape_shops_all)
df_1
# Out:
#                          address                        company  \
# 0   1724 N SALISBURY BLVD UNIT 2                    AMIN NARGIS
# 1          1015 S SALISBURY BLVD                    AMIN NARGIS
# 2        2299 JOHNS HOPKINS ROAD          ANJ DISTRIBUTIONS LLC
# 3                110 S. PINEY RD      COX TRADING COMPANY L L C
# 4            346 RITCHIE HIGHWAY                COX TRADING LLC
# 5        185 MITCHELLS CHANCE RD  DISBROW II EMERSON HARRINGTON
# 6          7104 MINSTREL UNIT #7     DISCOUNT TOBACCO ESSEX LLC
# 7     330 ONE FORTY VILLAGE ROAD         FAIRGROUND VILLAGE LLC
# 8         29890 THREE NOTCH ROAD                 GRIMM JENNIFER
# 9             356 ROMANCOKE ROAD                HUTCH VAPES LLC
# 10     110 S PINEY ROAD  STE 106               HUTCHINS COX LLP
# 11        28943 THREE NOTCH ROAD                JAMESON WILLIAM
# 12            6843 CRAIN HIGHWAY              JAMESON WILLIAM E
# 13           6321 OLD BRANCH AVE                JEFFERS MICHAEL
# 14           6321 OLD BRANCH AVE              JEFFERS MICHAEL W
# 15             7954 B AND A BLVD                   SHIN JENNY Y
# 16          6325 WASHINGTON BLVD               SHIN JENNY YOUNG
# 17           3203 NORTH POINT RD                  TAYLOR TRAVIS
# 18      519 LINDEN AVENUE UNIT 6            TRUE ENTERPRISE INC
# 19         16521 S FREDERICK AVE              VAPE  SOCIAL  LLC
# 20    2070 CRAIN HIGHWAY  UNIT F                VAPE JUNGLE LLC
# 21      4130 E JOPPA RD UNIT 109                  VAPE TIME LLC
# 22             11110 MALL CIRCLE            VAPEBAR EXPRESS LLC
# 23                3524 CRAIN HWY                   VAPOR 99 LLC
# 24    8117 OCEAN GATEWAY UNIT #4                VAPOR ALLEY LLC
# 25       11717 OLD NATIONAL PIKE          VAPOR EMPORIUM MD LLC
# 26   1913 LANSDOWNE ROAD SUITE E               VAPOR VILLA CORP
# 27            730 FREDERICK ROAD               VAPOR VILLA CORP
# 28             138 N BOND STREET          WALKER TRADING CO INC
# 29    11600 CROSSROAD CIR  STE E     WALKER TRADING COMPANY INC
# 30    11600 CROSSROAD CIR  STE E     WALKER TRADING COMPANY INC
# 31                3315 PLAZA WAY           YARKHOUSE EMPIRE INC
#
#                       county header issued date   license         shop name  \
# 0        SALISBURY, MD 21801     1.   4/27/2017  22173807   VAPE IT STORE I
# 1        SALISBURY, MD 21801     2.   4/27/2017  22173808  VAPE IT STORE II
# 2        GAMBRILLS, MD 21054     3.   4/05/2017  02104436       VAPEPAD THE
# 3          CHESTER, MD 21619     4.   5/31/2017  17165957         VAPE FROG
# 4     SEVERNA PARK, MD 21146     5.   5/31/2017  17165957         VAPE FROG
# 5        EDGEWATER, MD 21037     6.   4/13/2017  02102408   VAPE LOFT (THE)
# 6         COLUMBIA, MD 21045     7.   5/19/2017  13141786      VAPE N CIGAR
# 7      WESTMINSTER, MD 21157     8.   4/21/2017  06126253         VAPE DOJO
# 8   CHARLOTTE HALL, MD 20622     9.   4/21/2017  06126253        VAPE HAVEN
# 9     STEVENSVILLE, MD 21666    10.   4/13/2017  17166688         VAPE BIRD
# 10         CHESTER, MD 21619    11.   4/13/2017  17166688         VAPE FROG
# 11  MECHANICSVILLE, MD 20659    12.   5/17/2017  18167503     VAPORS LOUNGE
# 12        LA PLATA, MD 20646    13.   5/17/2017  18167503     VAPORS LOUNGE
# 13    CAMP SPRINGS, MD 20748    14.   5/17/2017  18167503         VAPIST MD
# 14    CAMP SPRINGS, MD 20748    15.   5/17/2017  18167503     VAPIST MD LLC
# 15     GLEN BURNIE, MD 21060    16.   5/17/2017  18167503        VAPERTETMD
# 16        ELKRIDGE, MD 21075    17.   5/17/2017  18167503        VAPERTEKMD
# 17       BALTIMORE, MD 21222    18.   5/17/2017  18167503          VAPORIOT
# 18   POCOMOKE CITY, MD 21851    19.   5/05/2017  23178140         VAPE PLUS
# 19    GAITHERSBURG, MD 20877    20.   4/18/2017  15155429      VAPE  SOCIAL
# 20         WALDORF, MD 20601    21.   3/31/2017  08131285       VAPE JUNGLE
# 21      NOTTINGHAM, MD 21236    22.   3/31/2017  08131285         VAPE TIME
# 22         WALDORF, MD 20603    23.   3/31/2017  08131285    VAPEBAR EXPESS
# 23           BOWIE, MD 20716    24.   5/03/2017  16165362          VAPOR 99
# 24          EASTON, MD 21601    25.   5/10/2017  20170900       VAPOR ALLEY
# 25      NEW MARKET, MD 21774    26.   4/14/2017  10135432    VAPOR EMPORIUM
# 26       BALTIMORE, MD 21227    27.   4/12/2017  03121958       VAPOR VILLA
# 27     CATONSVILLE, MD 21228    28.   4/12/2017  03121959       VAPOR VILLA
# 28         BEL AIR, MD 21014    29.   4/03/2017  12140135         VAPE DOJO
# 29       BALTIMORE, MD 21220    30.   4/03/2017  12140135         VAPE DOJO
# 30       BALTIMORE, MD 21220    31.   4/03/2017  12140135         VAPE DOJO
# 31         WALDORF, MD 20603    32.   4/03/2017  12140135   VAPEZ YARDHOUSE
#
#      status
# 0    Issued
# 1    Issued
# 2    Issued
# 3    Issued
# 4   Pending
# 5    Issued
# 6    Issued
# 7    Issued
# 8   Pending
# 9    Issued
# 10  Pending
# 11   Issued
# 12  Pending
# 13  Pending
# 14  Pending
# 15  Pending
# 16  Pending
# 17  Pending
# 18   Issued
# 19   Issued
# 20   Issued
# 21  Pending
# 22  Pending
# 23   Issued
# 24   Issued
# 25   Issued
# 26   Issued
# 27   Issued
# 28   Issued
# 29  Pending
# 30  Pending
# 31  Pending

# %%
df_1.to_csv("vape-results-all.csv", index=False)
