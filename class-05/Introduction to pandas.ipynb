# %%
import pandas as pd

# %%
df = pd.read_csv("countries.csv")
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.dtypes
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %%
df.sort_values(by="Population", ascending=False)
# Out:
#                               Country   Continent  GDP_per_capita  \
# 34                              China        Asia            3407
# 75                              India        Asia            1648
# 178                     United States  N. America           39758
# 76                          Indonesia        Asia            2714
# 22                             Brazil  S. America            8056
# 137                            Russia        Asia            8570
# 127                          Pakistan        Asia            2086
# 12                         Bangladesh        Asia            1075
# 83                              Japan        Asia           28559
# 124                           Nigeria      Africa            1619
# 110                            Mexico  N. America           10894
# 61                            Germany      Europe           29726
# 183                           Vietnam        Asia            1577
# ...

# %%
df.sort_values?

# %%
# each column is a series
df["Population"]
# Out:
# 0       22856302
# 1        3071856
# 2       30533827
# 3       13926373
# 4          77656
# 5       36930709
# 6        3076098
# 7       19164351
# 8        8004712
# 9        8110723
# 10        297651
# 11        638193
# 12     129592275
# 13        267511
# 14      10057810
# 15      10175684
# 16        250512
# 17       6517810
# 18        571262
# 19       8307248
# 20       3693698
# 21       1757925
# 22     174425387
# 23        327036
# 24       8006158
# 25      12294012
# 26       6374347
# 27      12446949
# 28      15678269
# 29      30667365
#          ...
# 158       466846
# 159      1063832
# 160      8860153
# 161      7167908
# 162     15988534
# 163     22183000
# 164      6172807
# 165     34038161
# 166     63155029
# 167       830089
# 168      4793504
# 169        97935
# 170      1292058
# 171      9456117
# 172     63627862
# 173      4501419
# 174     24213120
# 175     48891792
# 176      3033491
# 177     58874117
# 178    282496310
# ...

# %%
df["Population"].sum()
# Out:
# 6115042358

# %%
df["Population"].mean()
# Out:
# 32526821.05319149

# %%
df['Population'].std()
# Out:
# 123795162.37011255

# %%
df['Population'].describe().astype(int)
# Out:
# count           188
# mean       32526821
# std       123795162
# min           56196
# 25%         2003169
# 50%         6888970
# 75%        22185170
# max      1269116737
# Name: Population, dtype: int64

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df['Continent'].value_counts().plot()

# %%
# matplotlib is a Python graphing library
# use % to change notebook to graphing 
# %matplotlib inline
df['Continent'].value_counts().plot(kind='bar')

# %%
df['Continent'].value_counts().plot(kind='barh')

# %%
df.plot(kind='scatter', x="GDP_per_capita", y="life_expectancy")

# %%
# what column to group by
# what column we want information about
# and what information we want from that column
df.groupby('Continent')['GDP_per_capita'].mean().astype(int)
# Out:
# Continent
# Africa         2621
# Asia          11106
# Europe        18647
# N. America    11665
# Oceania        8038
# S. America     6738
# Name: GDP_per_capita, dtype: int64

# %%
df.shape
# Out:
# (188, 5)

# %%
df['Continent'] == 'Asia'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 158    False
# 159    False
# 160    False
# 161    False
# 162     True
# 163     True
# 164     True
# 165    False
# 166     True
# 167     True
# 168    False
# 169    False
# 170    False
# 171    False
# 172     True
# 173     True
# 174    False
# 175    False
# 176     True
# 177    False
# 178    False
# 179    False
# 180     True
# 181    False
# 182    False
# 183     True
# 184     True
# 185     True
# 186    False
# 187    False
# Name: Continent, Length: 188, dtype: bool

# %%
# df[   ] on the outside 
# and your conditional on the inside
df[df['Continent'] == 'Asia']
# Out:
#                   Country Continent  GDP_per_capita  life_expectancy  \
# 0             Afghanistan      Asia             663           54.863
# 11                Bahrain      Asia           22015           74.497
# 12             Bangladesh      Asia            1075           65.309
# 18                 Bhutan      Asia            2922           60.307
# 23                 Brunei      Asia           48020           75.927
# 27               Cambodia      Asia             982           62.030
# 34                  China      Asia            3407           72.124
# 72       Hong Kong, China      Asia           29972           80.361
# 75                  India      Asia            1648           62.129
# 76              Indonesia      Asia            2714           67.289
# 77                   Iran      Asia            8600           69.611
# 78                   Iraq      Asia            3951           70.845
# 80                 Israel      Asia           22834           78.750
# ...

# %%
df['GDP_per_capita'] > df['GDP_per_capita'].mean()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6      False
# 7       True
# 8       True
# 9      False
# 10      True
# 11      True
# 12     False
# 13      True
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 158    False
# 159    False
# 160     True
# 161     True
# 162    False
# 163     True
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170     True
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176     True
# 177     True
# 178     True
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# Name: GDP_per_capita, Length: 188, dtype: bool

# %%
df['Millions'] = df['Population'] / 1000000
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population   Millions
# 0    22856302  22.856302
# 1     3071856   3.071856
# 2    30533827  30.533827
# 3    13926373  13.926373
# 4       77656   0.077656

# %%
df['GDP_total_million'] = df['GDP_per_capita'] * df['Population'] / 1000000
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population   Millions  GDP_total_million
# 0    22856302  22.856302       15153.728226
# 1     3071856   3.071856       12886.435920
# 2    30533827  30.533827      155661.450046
# 3    13926373  13.926373       34063.908358
# 4       77656   0.077656         989.182128
