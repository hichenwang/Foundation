# %% [markdown]
# # A dataset about cans of beer.
#
# Data from http://craftcans.com/

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Read in the file `craftcans.csv`, and look at the first first rows

# %%
df = pd.read_csv("craftcans.csv", na_values=['???'])
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV  IBUs
# 0  16 oz.  4.50%  50.0
# 1  16 oz.  4.90%  26.0
# 2  16 oz.  4.80%  19.0
# 3  16 oz.  6.00%  38.0
# 4  16 oz.  6.00%  25.0

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.dtypes
# Out:
# Beer         object
# Brewery      object
# Location     object
# Style        object
# Size         object
# ABV          object
# IBUs        float64
# dtype: object

# %% [markdown]
# # Checking out breweries
#
# Where does beer come from????

# %% [markdown]
# ## What are the top 10 producers of cans of beer?

# %%
df['Brewery'].value_counts().head(10)
# Out:
# Brewery Vivant                62
# Oskar Blues Brewery           46
# Sun King Brewing Company      38
# Cigar City Brewing Company    25
# Sixpoint Craft Ales           24
# Hopworks Urban Brewery        23
# Stevens Point Brewery         22
# Great Crescent Brewery        20
# 21st Amendment Brewery        20
# SanTan Brewing Company        19
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What is the most common size of beer?
#
# The answer won't be pretty - we'll learn to clean it up in a week or two.

# %%
# learn to clean it up later
df['Size'].value_counts().head(1)
# Out:
# 12 oz.    1507
# Name: Size, dtype: int64

# %% [markdown]
# ## What is the most common ABV? (alcohol by volume)

# %%
df['ABV'].value_counts().head(1)
# Out:
# 5.00%    215
# Name: ABV, dtype: int64

# %% [markdown]
# ## Oh, weird, ABV isn't a number. Convert it to a number for me, please.
#
# It's going to take three steps:
#
# 1. List just the ABV of every row
# 2. Remove the % symbol
# 3. Convert it to a `float`
# 4. Save it into a new column. Or the same column, if you're feeling wild.
#
# Although it *also* turns out that there's some bad data in there. We'll need to clean that up, too.

# %%
df['ABV'].str.replace("%", "")
# Out:
# 0        4.50
# 1        4.90
# 2        4.80
# 3        6.00
# 4        6.00
# 5        5.60
# 6        8.00
# 7       12.50
# 8        7.70
# 9        4.20
# 10       5.00
# 11       6.60
# 12       4.00
# 13       5.50
# 14       7.60
# 15       5.10
# 16       6.50
# 17       6.00
# 18       5.00
# 19       5.20
# 20       4.80
# 21       7.20
# 22       6.70
# 23       4.90
# 24       8.00
# 25       7.50
# 26       6.00
# 27       8.00
# 28       6.30
# 29       5.80
#         ...
# 2386     5.70
# 2387     6.20
# 2388     4.90
# 2389     9.90
# 2390     6.20
# 2391     5.80
# 2392     5.20
# 2393     8.50
# 2394     7.00
# 2395     5.30
# 2396     5.60
# 2397     4.90
# 2398     5.10
# 2399     4.00
# 2400     5.50
# 2401     5.10
# 2402     5.10
# 2403     9.70
# 2404     5.10
# 2405     6.70
# 2406     6.20
# 2407     8.30
# 2408     7.00
# 2409     4.90
# 2410     9.90
# 2411     5.30
# 2412     9.90
# 2413     8.00
# 2414     8.70
# 2415     6.50
# Name: ABV, Length: 2416, dtype: object

# %%
df['ABV'] = df['ABV'].str.replace("%", "")

# %%
df['ABV_new'] = df['ABV'].astype(float)

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size   ABV  IBUs  ABV_new
# 0  16 oz.  4.50  50.0      4.5
# 1  16 oz.  4.90  26.0      4.9
# 2  16 oz.  4.80  19.0      4.8
# 3  16 oz.  6.00  38.0      6.0
# 4  16 oz.  6.00  25.0      6.0

# %% [markdown]
# # Looking at location
#
# Brooklyn used to produce 80% of the country's beer! Let's see if it's still true.

# %% [markdown]
# ## What are the top 10 cities in the US for canned craft beer?

# %%
df['Location'].value_counts().head(10)
# Out:
# Grand Rapids, MI    66
# Chicago, IL         55
# Portland, OR        52
# Indianapolis, IN    43
# San Diego, CA       42
# Boulder, CO         41
# Denver, CO          40
# Brooklyn, NY        38
# Seattle, WA         35
# Longmont, CO        33
# Name: Location, dtype: int64

# %% [markdown]
# ## List all of the beer from Brooklyn, NY

# %%
df[df['Location'] == 'Brooklyn, NY']
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 404                     Nomader Weiss    Evil Twin Brewing  Brooklyn, NY
# 421                               Rad  Sixpoint Craft Ales  Brooklyn, NY
# 439                      Molotov Lite    Evil Twin Brewing  Brooklyn, NY
# 588                           Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 713                     Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 969                            Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 987             KelSo Nut Brown Lager   KelSo Beer Company  Brooklyn, NY
# 1057                    Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 1074               Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# 1093             KelSo India Pale Ale   KelSo Beer Company  Brooklyn, NY
# 1267                        The Crisp  Sixpoint Craft Ales  Brooklyn, NY
# 1268                     Sweet Action  Sixpoint Craft Ales  Brooklyn, NY
# 1269                    Righteous Ale  Sixpoint Craft Ales  Brooklyn, NY
# 1270                    Bengali Tiger  Sixpoint Craft Ales  Brooklyn, NY
# 1305                    KelSo Pilsner   KelSo Beer Company  Brooklyn, NY
# 1365  Hipster Ale (Two Roads Brewing)    Evil Twin Brewing  Brooklyn, NY
# 1366                      Bikini Beer    Evil Twin Brewing  Brooklyn, NY
# 1972  American Double / Imperial IPA             12 oz.   9.10  103.0      9.1
# 2027    English India Pale Ale (IPA)             12 oz.   6.80   47.0      6.8
# 2062                  American Stout             16 oz.   6.30   69.0      6.3
# 2074                     Pumpkin Ale             16 oz.   6.00   48.0      6.0
# 2140                 German Pilsener             16 oz.   5.40   42.0      5.4
# 2141                       Cream Ale             16 oz.   5.20   34.0      5.2
# 2142                        Rye Beer             16 oz.   6.30   57.0      6.3
# 2143                    American IPA             16 oz.   6.40   62.0      6.4
# 2219           English Pale Mild Ale             12 oz.   4.50    NaN      4.5
# 2350      American Amber / Red Lager             16 oz.   5.20    NaN      5.2
# 2351      American Amber / Red Lager             12 oz.   5.20    NaN      5.2

# %% [markdown]
# ## What brewery in Brooklyn puts out the most cans of beer?

# %%
df[df['Location'] == 'Brooklyn, NY']['Brewery'].value_counts().head(1)
# Out:
# Sixpoint Craft Ales    24
# Name: Brewery, dtype: int64

# %% [markdown]
# ## What are the five most popular styles of beer produced by Sixpoint?

# %%
df_brewery_brooklyn = df[df['Location'] == 'Brooklyn, NY']
df_brewery_brooklyn[df_brewery_brooklyn['Brewery'] == 'Sixpoint Craft Ales']['Style'].value_counts().head(6)
# Out:
# American IPA                      4
# Rye Beer                          2
# Cream Ale                         2
# German Pilsener                   2
# Baltic Porter                     2
# American Double / Imperial IPA    2
# Name: Style, dtype: int64

# %% [markdown]
# ## List all of the breweries in New York state. Then count them.

# %%
df[df['Location'].str.contains("NY", na=False)]['Brewery'].value_counts().count()
# Out:
# 16

# %% [markdown]
# # Measuring International Bitterness Units
#
# IBU stands for [International Bitterness Unit](http://www.thebrewenthusiast.com/ibus/), and while a lot of places like to brag about having the most bitter beer (it's an American thing!), IBUs don't necessary *mean anything*.
#
# Let's look at how different beers have different IBU measurements.

# %%
df[["Beer", "IBUs"]]
# Out:
#                                        Beer   IBUs
# 0                              Get Together   50.0
# 1                             Maggie's Leap   26.0
# 2                                Wall's End   19.0
# 3                                   Pumpion   38.0
# 4                                Stronghold   25.0
# 5                               Parapet ESB   47.0
# 6                            Citra Ass Down   68.0
# 7                            London Balling   80.0
# 8                                      35 K   25.0
# 9                                    A Beer   42.0
# 10                          Rules are Rules   25.0
# 11                            Flesh Gourd'n   21.0
# 12                                 Sho'nuff   13.0
# 13                              Bloody Show   17.0
# 14                              Rico Sauvin   68.0
# 15                         Coq de la Marche   38.0
# 16                           Kamen Knuddeln    NaN
# 17                             Pile of Face   65.0
# 18                           The Brown Note   20.0
# 19                              House Lager   18.0
# 20                             Leisure Time   15.0
# 21                               Excess IPL   80.0
# 22                           Hoponius Union   65.0
# 23                                 Calyptra   45.0
# 24                           Habitus (2014)  100.0
# 25                                    Solis   85.0
# 26                                 Jucundus   24.0
# 27                                  Habitus  100.0
# 28                                  Grazias   30.0
# 29                                 Claritas   28.0
# ...                                     ...    ...
# 2386                         CoCoNut Porter   30.0
# 2387                          Big Swell IPA   65.0
# 2388              Urban Wilderness Pale Ale    NaN
# 2389             Very Noddy Lager (Current)    NaN
# 2390            Tule Duck Red Ale (Current)   42.0
# 2391  Original Orange Blossom Ale (Current)   35.0
# 2392            Black Noddy Lager (Current)   40.0
# 2393                           Siamese twin    NaN
# 2394                                113 IPA  113.0
# 2395                           Dunkel Lager   21.0
# 2396                       Royal Weisse Ale   11.0
# 2397                          Pikeland Pils   44.0
# 2398                       Phoenix Pale Ale   40.0
# 2399                          Bitter Brewer   37.0
# 2400                              SurlyFest   34.0
# 2401                          Coffee Bender   45.0
# 2402                                 Bender   45.0
# 2403                           Abrasive Ale  120.0
# 2404                                   Hell   20.0
# 2405                               CynicAle   33.0
# 2406                                Furious   99.0
# 2407                           Monk's Blood   35.0
# 2408                  Brew Free! or Die IPA   65.0
# 2409          Hell or High Watermelon Wheat   17.0
# 2410                Ten Fidy Imperial Stout   98.0
# 2411               Mama's Little Yella Pils   35.0
# 2412                     GUBNA Imperial IPA  100.0
# 2413                               Old Chub   35.0
# 2414                      Gordon Ale (2009)   85.0
# 2415                        Dale's Pale Ale   65.0
#
# [2416 rows x 2 columns]

# %% [markdown]
# ## What is the average IBU measurement across all beers?

# %%
df['IBUs'].mean()
# Out:
# 42.713167259786474

# %% [markdown]
# ## Draw the distribution of IBU measurements, but with *thirty* bins instead of the default of 10

# %%
df['IBUs'].hist(bins = 30)

# %% [markdown]
# ## List all of the beers with IBUs above the 75th percentile

# %%
df_above_median_ibus = df[df['IBUs'] > df['IBUs'].median()]
df_above_75_ibus = df[df['IBUs'] > df_above_median_ibus['IBUs'].median()]
df_above_75_ibus
# Out:
#                                  Beer                             Brewery  \
# 6                      Citra Ass Down           Against the Grain Brewery
# 7                      London Balling           Against the Grain Brewery
# 14                        Rico Sauvin           Against the Grain Brewery
# 21                         Excess IPL            Jack's Abby Craft Lagers
# 24                     Habitus (2014)           Mike Hess Brewing Company
# 25                              Solis           Mike Hess Brewing Company
# 27                            Habitus           Mike Hess Brewing Company
# 46                Yeti Imperial Stout        Great Divide Brewing Company
# 62                       Train Hopper         Witch's Hat Brewing Company
# 68                               Csar             Tin Man Brewing Company
# 69                     Saucy Intruder              Black Acre Brewing Co.
# 79                         The Gadget                Four Fathers Brewing
# 89                         Gone A-Rye                 Cedar Creek Brewery
# 93                      Heavy Lifting           Boulevard Brewing Company
# 110                           Jah Mon          Rivertowne Brewing Company
# 123                    Flying Mouse 4                Flying Mouse Brewery
# 149                    Citra Ass Down           Against The Grain Brewery
# 168                        Soul Doubt            Freetail Brewing Company
# 170                      Bimini Twist                 3 Daughters Brewing
# 178                         Long Leaf        Appalachian Mountain Brewery
# 182                    Double Duckpin                 Union Craft Brewing
# 186                        Hop A-Peel                     Atwater Brewery
# 192                            Wobble        Two Brothers Brewing Company
# 218                  Hopkick Dropkick                    Burn 'Em Brewing
# 226                        Union Jack    Firestone Walker Brewing Company
# 239                      Self Starter         Warped Wing Brewing Company
# 245                     Nugget Nectar              Tröegs Brewing Company
# 248                       Mission IPA                     Mission Brewery
# 249   Bay of Bengal Double IPA (2014)  Christian Moerlein Brewing Company
# 252                 Newport Storm IPA     Coastal Extreme Brewing Company
# ...                               ...                                 ...
# 2133                       Hop Crisis              21st Amendment Brewery
# 2135     Hop Slayer Double IPA (2011)          Wild Onion Brewing Company
# 2137                        Shiva IPA           Asheville Brewing Company
# 2150                    Anti-Hero IPA          Revolution Brewing Company
# 2225   85.0      8.8
# 2228   97.0      7.4
# 2229   85.0      7.0
# 2234  103.0      9.3
# 2252   68.0      6.2
# 2257   80.0      6.5
# 2261   69.0      6.9
# 2306   70.0      6.5
# 2313   69.0      6.3
# 2316   93.0      7.2
# 2369   82.0      8.4
# 2375   85.0      8.8
# 2382   94.0      6.1
# 2394  113.0      7.0
# 2403  120.0      9.7
# 2406   99.0      6.2
# 2410   98.0      9.9
# 2412  100.0      9.9
# 2414   85.0      8.7
#
# [292 rows x 8 columns]

# %% [markdown]
# ## List all of the beers with IBUs below the 25th percentile

# %%
df_below_median_ibus = df[df['IBUs'] < df['IBUs'].median()]
df_below_25_ibus = df[df['IBUs'] < df_below_median_ibus['IBUs'].median()]
df_below_25_ibus
# Out:
#                                         Beer  \
# 2                                 Wall's End
# 12                                  Sho'nuff
# 13                               Bloody Show
# 19                               House Lager
# 20                              Leisure Time
# 30                                      Park
# 31                                 Westfalia
# 32                                       KSA
# 54                                   Sparkle
# 56                              Hotbox Brown
# 57                                      Gold
# 67                    Damascene Apricot Sour
# 102                           Vanilla Porter
# 105                                     Gose
# 139                            Weissenheimer
# 144                    Passion Fruit Prussia
# 145                                Send Help
# 159                                Daft Funk
# 167                                  Rye Wit
# 169                       Yo Soy Un Berliner
# 173                 Farmer's Daughter Blonde
# 177                                Honey Rye
# 179                      Honey Badger Blonde
# 183                                  Old Pro
# 187                      Vanilla Java Porter
# 204                   Saddle Bronc Brown Ale
# 210                                   Jammer
# 230                         Blackberry Wheat
# 251                   Rhode Island Blueberry
# 254                           Watermelon Ale
# ...                                      ...
# 2165                   Wild Onion Summer Wit
# 2166                        SummerBright Ale
# 2172                                 Whitsun
# 2176                          Mexican Logger
# 2184                                  Festie
# 2191                         Blacktop Blonde
# 2232                 Narragansett Fest Lager
# 2233                              Mana Wheat
# 2241                SanTan HefeWeizen (2010)
# 2268             Flaming Damsel Lager (2010)
# 2275  Black Star Double Hopped Golden Lager
# 2289    Point Nude Beach Summer Wheat (2010)
# 2291                     Point Amber Classic
# 2292                     Point Special Lager
# 2296            Morning Wood Wheat (Current)
# 2298                         O'Fallon Wheach
# 2312                            White Rascal
# 2314                       Ellie’s Brown Ale
# 2315                       Köld Lager (2010)
# 2324                         Colorado Kölsch
# 2331                   Cold Smoke Scotch Ale
# 2333                           Avalanche Ale
# 2334               Haywire Hefeweizen (2010)
# 2338                  Boont Amber Ale (2011)
# 2339                  Summer Solstice (2011)
# 2345               Fat Tire Amber Ale (2008)
# 2363                   Schlafly Summer Lager
# 2385                     Bikini Blonde Lager
# 2396                        Royal Weisse Ale
# 2409           Hell or High Watermelon Wheat
#
#                                   Brewery             Location  \
# 2                       NorthGate Brewing      Minneapolis, MN
# 12              Against the Grain Brewery       Louisville, KY
# 13              Against the Grain Brewery       Louisville, KY
# 19               Jack's Abby Craft Lagers       Framingham, MA
# 20               Jack's Abby Craft Lagers       Framingham, MA
# 30                Fort Point Beer Company    San Francisco, CA
# 31                Fort Point Beer Company    San Francisco, CA
# 32                Fort Point Beer Company    San Francisco, CA
# 54                       Petoskey Brewing         Petoskey, MI
# 56                 Perrin Brewing Company    Comstock Park, MI
# 2396                  Hefeweizen           12 oz.  5.60  11.0      5.6
# 2409      Fruit / Vegetable Beer           12 oz.  4.90  17.0      4.9
#
# [256 rows x 8 columns]

# %% [markdown]
# ## List the median IBUs of each type of beer. Graph it.
#
# Put the highest at the top, and the nan ones at the bottom. I want a nice graph, too - don't let them all be squished together, either!

# %%
df_ibus_notnull = df[df['IBUs'].notnull()]
df_ibus_notnull.groupby('Style')['IBUs'].median().sort_values(ascending=False)#.plot(kind='barh')
df.groupby('Style')['IBUs'].median().sort_values(ascending=True, na_position='first').plot(kind='barh', figsize=(10,30))

# %% [markdown]
# ## Hmmmm, it looks like they are generally different styles. What are the most common 5 styles of high-IBU beer vs. low-IBU beer?
#
# You'll want to think about it in three pieces - finding the high IBU beers, then finding out what the most common styles are, then getting the top 5.

# %%
df_above_75_ibus['Style'].value_counts().head()
# Out:
# American IPA                      165
# American Double / Imperial IPA     72
# American Black Ale                 12
# American Strong Ale                 9
# Russian Imperial Stout              7
# Name: Style, dtype: int64

# %%
df_below_25_ibus['Style'].value_counts().head()
# Out:
# American Pale Wheat Ale    28
# American Blonde Ale        25
# Fruit / Vegetable Beer     24
# Hefeweizen                 21
# Witbier                    17
# Name: Style, dtype: int64

# %% [markdown]
# ## Get the average IBU of "Witbier", "Hefeweizen" and "American Pale Wheat Ale" styles (also draw a histogram)
#
# I want ONE measurement and ONE graph, not three separate ones. And 20 to 30 bins in the histogram, please.

# %%
df[df['Style'].isin(["Witbier", "Hefeweizen", "American Pale Wheat Ale" ])]['IBUs'].mean()
# Out:
# 18.982142857142858

# %%
df[df['Style'].isin(["Witbier", "Hefeweizen", "American Pale Wheat Ale" ])]['IBUs'].hist(bins=30)

# %% [markdown]
# ## Get the average IBU of any style with "IPA" in it (also draw a histogram)

# %%
df[df['Style'].str.contains("IPA", na=False)]['IBUs'].mean()
# Out:
# 71.948979591836732

# %%
df[df['Style'].str.contains("IPA", na=False)]['IBUs'].hist(bins=30)

# %% [markdown]
# ## Plot those two histograms on top of one another

# %%
ax = df[df['Style'].isin(["Witbier", "Hefeweizen", "American Pale Wheat Ale" ])]['IBUs'].hist(bins=30, color='orange')
df[df['Style'].str.contains("IPA", na=False)]['IBUs'].hist(bins=30, color='green', alpha=0.4, ax=ax)
ax.legend(['Witbier", "Hefeweizen", "American Pale Wheat Ale', 'ipa'])

# %% [markdown]
# ## Compare the ABV of wheat beers vs. IPAs

# %%
ax2 = df[df['Style'].str.contains("IPA", na=False)]['ABV_new'].hist(bins=40, color='orange')
df[df['Style'].str.contains("Wheat", na=False)]['ABV_new'].hist(bins=40, color='green', ax=ax2)
ax2.legend(['IPA', 'Wheat'])

# %%
df[df['Style'].str.contains("IPA", na=False)]['ABV_new'].describe()
# Out:
# count    560.000000
# mean       6.879286
# std        1.240232
# min        2.700000
# 25%        6.200000
# 50%        6.800000
# 75%        7.500000
# max        9.900000
# Name: ABV_new, dtype: float64

# %%
df[df['Style'].str.contains("Wheat", na=False)]['ABV_new'].describe()
# Out:
# count    102.000000
# mean       4.875490
# std        0.660998
# min        3.900000
# 25%        4.500000
# 50%        4.800000
# 75%        5.200000
# max        6.800000
# Name: ABV_new, dtype: float64
